# %%
import pandas as pd
df = pd.read_csv("https://raw.githubusercontent.com/balaji2v/Inceptez_Batch19/main/Demand_txn_updated.csv")
print(df.head(15))
# Out:
#          City Mapped_Sales_Type  Mapped_Item_Code Transaction_Date  \
# 0   Hyderabad         Take Away              9978        7/31/2018
# 1   Hyderabad         Take Away              4064        7/31/2018
# 2   Hyderabad         Main Hall               965        7/31/2018
# 3   Hyderabad           Express              9978        7/31/2018
# 4   Hyderabad           Express              1045        7/31/2018
# 5   Hyderabad          Delivery              4056        7/31/2018
# 6   Hyderabad         Take Away              4065        7/31/2018
# 7   Hyderabad           Express              4058        7/31/2018
# 8   Hyderabad           Express              4057        7/31/2018
# 9   Hyderabad           Express              4056        7/31/2018
# 10  Hyderabad          Delivery              4061        7/31/2018
# 11  Hyderabad           Express              4055        7/31/2018
# 12  Hyderabad         Take Away              4061        7/31/2018
# ...

# %%
df.dtypes
# Out:
# City                                           object
# Mapped_Sales_Type                              object
# Mapped_Item_Code                                int64
# Transaction_Date                               object
# Quantity_Sold                                   int64
# Median_Price                                  float64
# Average_Tax_Percent                           float64
# Effective_Price                               float64
# Percent_Quantity_With_Discount                float64
# Avg_Discount_Percent_On_Discounted_Items      float64
# Year                                            int64
# Month                                           int64
# Day                                            object
# Car_sales                                     float64
# F_and_B_Inflation                             float64
# F_and_B_Inflation_Adjusted_Effective_Price    float64
# F_and_B_Inflation_Adjusted_Median_Price       float64
# ...

# %%
df["Transaction_Date"]= pd.to_datetime(df["Transaction_Date"])
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30231 entries, 0 to 30230
# Data columns (total 22 columns):
#  #   Column                                      Non-Null Count  Dtype
# ---  ------                                      --------------  -----
#  0   City                                        30231 non-null  object
#  1   Mapped_Sales_Type                           30231 non-null  object
#  2   Mapped_Item_Code                            30231 non-null  int64
#  3   Transaction_Date                            30231 non-null  datetime64[ns]
#  4   Quantity_Sold                               30231 non-null  int64
#  5   Median_Price                                30231 non-null  float64
#  6   Average_Tax_Percent                         30231 non-null  float64
#  7   Effective_Price                             30229 non-null  float64
#  8   Percent_Quantity_With_Discount              12209 non-null  float64
# ...

# %%
subset_df = df.loc[(df['Transaction_Date'] > '2016-08-01')]
print(subset_df)
# Out:
#             City Mapped_Sales_Type  Mapped_Item_Code Transaction_Date  \
# 0      Hyderabad         Take Away              9978       2018-07-31
# 1      Hyderabad         Take Away              4064       2018-07-31
# 2      Hyderabad         Main Hall               965       2018-07-31
# 3      Hyderabad           Express              9978       2018-07-31
# 4      Hyderabad           Express              1045       2018-07-31
# ...          ...               ...               ...              ...
# 30187     Mumbai         Take Away              4059       2016-08-02
# 30188     Mumbai         Main Hall               966       2016-08-02
# 30189     Mumbai         Take Away              4065       2016-08-02
# 30190     Mumbai          Delivery              4057       2016-08-02
# 30191     Mumbai         Take Away              4061       2016-08-02
#
#        Quantity_Sold  Median_Price  Average_Tax_Percent  Effective_Price  \
# ...

# %%
uniq = pd.unique(df['Mapped_Sales_Type'])
print(uniq)
# Out:
# ['Take Away' 'Main Hall' 'Express' 'Delivery' 'Dine-in' 'Bakery']

# %%
new_df = df.loc[(df['Avg_Discount_Percent_On_Discounted_Items'] < 1.0)]
print(new_df)
# Out:
#             City Mapped_Sales_Type  Mapped_Item_Code Transaction_Date  \
# 5      Hyderabad          Delivery              4056       2018-07-31
# 10     Hyderabad          Delivery              4061       2018-07-31
# 20     Hyderabad           Dine-in               966       2018-07-31
# 24     Hyderabad           Dine-in               965       2018-07-31
# 26     Hyderabad          Delivery              4068       2018-07-31
# ...          ...               ...               ...              ...
# 30198     Mumbai         Take Away              4055       2016-08-01
# 30201     Mumbai           Dine-in               978       2016-08-01
# 30212     Mumbai           Dine-in               970       2016-08-01
# 30213     Mumbai           Dine-in               965       2016-08-01
# 30226     Mumbai         Take Away              4056       2016-08-01
#
#        Quantity_Sold  Median_Price  Average_Tax_Percent  Effective_Price  \
# ...

# %%
Check_sanity = df.loc[df['Avg_Discount_Percent_On_Discounted_Items'] >= 1.0] = 0 
print(Check_sanity)
print(df['Avg_Discount_Percent_On_Discounted_Items'])
# Out:
# 0
# 0             NaN
# 1        0.000000
# 2             NaN
# 3             NaN
# 4             NaN
#            ...
# 30226    0.883279
# 30227    0.000000
# 30228         NaN
# 30229         NaN
# 30230         NaN
# Name: Avg_Discount_Percent_On_Discounted_Items, Length: 30231, dtype: float64

# %%
df.groupby(['City','Mapped_Sales_Type','Mapped_Sales_Type','Transaction_Date'])['Quantity_Sold'].sum()
# Out:
# City     Mapped_Sales_Type  Mapped_Sales_Type  Transaction_Date
# 0        0                  0                  0                      0
# Chennai  Bakery             Bakery             1/22/2018            105
#                                                8/5/2017             110
#          Delivery           Delivery           1/1/2018            3887
#                                                1/10/2018           2929
#                                                                    ...
# Mumbai   Take Away          Take Away          9/5/2016            2786
#                                                9/6/2016            2514
#                                                9/7/2016            3691
#                                                9/8/2016            3981
#                                                9/9/2016            3457
# Name: Quantity_Sold, Length: 3271, dtype: int64

# %%
df.groupby(['City','Mapped_Sales_Type','Mapped_Sales_Type','Transaction_Date'])['Median_Price'].median()
# Out:
# City     Mapped_Sales_Type  Mapped_Sales_Type  Transaction_Date
# 0        0                  0                  0                     0.00
# Chennai  Bakery             Bakery             1/22/2018           178.00
#                                                8/5/2017            223.00
#          Delivery           Delivery           1/1/2018            566.43
#                                                1/10/2018           566.43
#                                                                     ...
# Mumbai   Take Away          Take Away          9/5/2016            492.22
#                                                9/6/2016            496.61
#                                                9/7/2016            496.61
#                                                9/8/2016            492.22
#                                                9/9/2016            496.61
# Name: Median_Price, Length: 3271, dtype: float64

# %%
df.groupby(['City','Mapped_Sales_Type','Mapped_Sales_Type','Transaction_Date'])['Effective_Price'].median()
# Out:
# City     Mapped_Sales_Type  Mapped_Sales_Type  Transaction_Date
# 0        0                  0                  0                     0.000000
# Chennai  Bakery             Bakery             1/22/2018           154.250000
#                                                8/5/2017            221.000000
#          Delivery           Delivery           1/1/2018            562.108288
#                                                1/10/2018           562.110000
#                                                                       ...
# Mumbai   Take Away          Take Away          9/5/2016            523.059109
#                                                9/6/2016            527.666813
#                                                9/7/2016            528.947080
#                                                9/8/2016            524.009245
#                                                9/9/2016            528.870785
# Name: Effective_Price, Length: 3271, dtype: float64

# %%
#df.groupby('group').agg({'a':['sum', 'max'],'b':'mean', 'c':'sum', 'd': lambda x: x.max() - x.min()}) to ask

# %%
Eff_Prc = pd.notnull(df['Effective_Price']).tail(5)
print(Eff_Prc)
# Out:
# 30226    True
# 30227    True
# 30228    True
# 30229    True
# 30230    True
# Name: Effective_Price, dtype: bool

# %%
df.loc[(df['City']=='Chennai') & (df['Mapped_Sales_Type']=='Delivery')].head(5)
# Out:
#          City Mapped_Sales_Type  Mapped_Item_Code Transaction_Date  \
# 8379  Chennai          Delivery              4055         2/5/2018
# 8384  Chennai          Delivery              4068         2/5/2018
# 8387  Chennai          Delivery              4064         2/5/2018
# 8388  Chennai          Delivery              4058         2/5/2018
# 8392  Chennai          Delivery              4061         2/5/2018
#
#       Quantity_Sold  Median_Price  Average_Tax_Percent  Effective_Price  \
# 8379            544        281.10                 0.05       262.502194
# 8384            129        566.43                 0.05       562.110000
# 8387            186        619.34                 0.05       617.659733
# 8388            287        259.19                 0.05       239.381307
# 8392            128        850.62                 0.05       855.697647
#
#       Percent_Quantity_With_Discount  \
# 8379                             NaN
# 8384                             NaN
# ...

# %%
df.loc[(df.Day.isin (['Mon','Tue','Wed']))]
# Out:
#             City Mapped_Sales_Type  Mapped_Item_Code Transaction_Date  \
# 0      Hyderabad         Take Away              9978        7/31/2018
# 1      Hyderabad         Take Away              4064        7/31/2018
# 2      Hyderabad         Main Hall               965        7/31/2018
# 3      Hyderabad           Express              9978        7/31/2018
# 4      Hyderabad           Express              1045        7/31/2018
# ...          ...               ...               ...              ...
# 30226     Mumbai         Take Away              4056         8/1/2016
# 30227     Mumbai         Take Away              4058         8/1/2016
# 30228     Mumbai           Dine-in               964         8/1/2016
# 30229     Mumbai         Take Away              4066         8/1/2016
# 30230     Mumbai          Delivery              4061         8/1/2016
#
#        Quantity_Sold  Median_Price  Average_Tax_Percent  Effective_Price  \
# ...

# %%
df.loc[(df['Percent_Quantity_With_Discount'] != 0.0)]
# Out:
#             City Mapped_Sales_Type  Mapped_Item_Code Transaction_Date  \
# 0      Hyderabad         Take Away              9978        7/31/2018
# 1      Hyderabad         Take Away              4064        7/31/2018
# 2      Hyderabad         Main Hall               965        7/31/2018
# 3      Hyderabad           Express              9978        7/31/2018
# 4      Hyderabad           Express              1045        7/31/2018
# ...          ...               ...               ...              ...
# 30226     Mumbai         Take Away              4056         8/1/2016
# 30227     Mumbai         Take Away              4058         8/1/2016
# 30228     Mumbai           Dine-in               964         8/1/2016
# 30229     Mumbai         Take Away              4066         8/1/2016
# 30230     Mumbai          Delivery              4061         8/1/2016
#
#        Quantity_Sold  Median_Price  Average_Tax_Percent  Effective_Price  \
# ...

# %%
df['Range'] = [1 if x > 500 else 0.5 for x in df['Effective_Price']]
print(df['Range'])
# Out:
# 0        0.5
# 1        1.0
# 2        0.5
# 3        0.5
# 4        0.5
#         ...
# 30226    0.5
# 30227    0.5
# 30228    1.0
# 30229    1.0
# 30230    1.0
# Name: Range, Length: 30231, dtype: float64

# %%
df['Percent_Quantity_With_Discount'].fillna(df['Percent_Quantity_With_Discount'].mean(),inplace=True)
print(df['Percent_Quantity_With_Discount'])
# Out:
# 0        0.098011
# 1        0.027237
# 2        0.098011
# 3        0.098011
# 4        0.098011
#            ...
# 30226    0.013889
# 30227    0.009338
# 30228    0.098011
# 30229    0.098011
# 30230    0.098011
# Name: Percent_Quantity_With_Discount, Length: 30231, dtype: float64
